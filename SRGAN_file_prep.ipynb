# %%
# This is made to claculate the numbers of images in the original_images folder 
import numpy as np
import os

count = 0
for img in os.listdir( "/content/drive/My Drive/Colab Notebooks/HighRes_SRGAN/Standardjpg/data/original_images"):
#for img in os.listdir( "/content/drive/My Drive/Colab Notebooks/HighRes_SRGAN/Standardjpg/data/lr_images"):
  #count =+1
  if img=="im5000.jpg":    #AP specify the name of the file
    print(img)
print(len(img))
# Out:
# im5000.jpg
# 10

# %%
import numpy as np
import os
from skimage.io import imread, imshow, imsave
from skimage.transform import resize

train_dir = "data" 
count = 0
for img in os.listdir( "/content/drive/My Drive/Colab Notebooks/HighRes_SRGAN/Standardjpg/data/original_images"):
    img_array = imread("/content/drive/My Drive/Colab Notebooks/HighRes_SRGAN/Standardjpg/data/original_images/" + img)[:,:]
    hr_img_array = resize(img_array, (128,128), mode='constant', preserve_range=True)
    lr_img_array = resize(img_array, (32,32), mode='constant', preserve_range=True)
    
    #print(img)

    imsave('/content/drive/My Drive/Colab Notebooks/HighRes_SRGAN/Standardjpg/data/hr_images/'+ img, hr_img_array)
    imsave('/content/drive/My Drive/Colab Notebooks/HighRes_SRGAN/Standardjpg/data/lr_images/'+ img, lr_img_array)

    count =+1
print(count)    
print(lr_img_array.shape)
print(hr_img_array.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0.0, 250.43749999999994]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [5.112304687499968, 253.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:imageio:Lossy conversion from float64 to uint8. Range [0.0, 251.84472656249994]. Convert image to uint8 prior to saving to suppress this warning.
# ...
